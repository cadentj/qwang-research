# %%
import osmnx as ox
import geopandas as gpd
import networkx as nx

# %%
PLACE_NAME = "Houston, Texas, United States"
home_addr = ox.graph_from_address(77401, network_type='all_private')

# %%
projected = ox.project_graph(home_addr)
ox.plot_graph(projected)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
home_addr.edges
# Out:
# OutMultiEdgeView([(151517184, 8907224589, 0), (151517184, 152230678, 0), (151597414, 313808237, 0), (151838834, 151838850, 0), (151838834, 3239819751, 0), (151838850, 151517184, 0), (151921629, 151921669, 0), (151921629, 2767326745, 0), (151921629, 152299267, 0), (151921669, 2844099285, 0), (151921679, 152299289, 0), (151921679, 151921699, 0), (151921699, 152299005, 0), (151921705, 2613489835, 0), (151921705, 151921732, 0), (151921732, 152299270, 0), (151921742, 152299007, 0), (151921742, 151921763, 0), (151921763, 152299292, 0), (151969400, 151969418, 0), (151969400, 152095218, 0), (151969418, 313809145, 0), (152092723, 152092726, 0), (152092723, 152280478, 0), (152092723, 152306590, 0), (152092726, 152092723, 0), (152092726, 152280425, 0), (152092726, 152306556, 0), (152094561, 152280468, 0), (152094561, 152280465, 0), (152094561, 152094563, 0), (152094563, 152094561, 0), (152094563, 152298974, 0), (152094579, 152133909, 0), (152094579, 152133907, 0), (152094579, 2277036279, 0), (1
# ...
